# %%
count=0
for x in [0,1,2,3]:
  if x:
    count+=1
print(count)
# Out:
# 3

# %%
def filter_positive(lst):
  result=[]
  for num in lst:
    if num>0 :
      result.append(num*2)
  return result
filter_positive([1,2,-3,4])
# Out:
# [2, 4, 8]

# %%
tuple=(1,2,3,4,5)
(*a,middle,b)=(1,2,3,4,5)
print(a)
# Out:
# [1, 2, 3]

# %%
def test_control(tup):
  count_even=0
  for val in tup:
    if val in tup:
      if val%2==0:
        count_even+=1
      elif val>2:
        break
  return count_even
test_control((1,2,3,4))
# Out:
# 1

# %%
s=0
for i in range(0,5):
 if i%2==1:
  s+=i
else:
  s-=i
print(s)
# Out:
# 0

# %%
days=[9,8,7,6]
window=[]
i=0
while i<len(days)-1:
  j=i+3
  while j<len(days):
    if days[j]-days[i]<=8:
      window.append((i,j))
    j+=2
  i+=1
print(window)
# Out:
# [(0, 3)]

# %%
nums=[1,2,7,4,9]
for i in range(len(nums)):
  nums[i]+=-2
print(nums)
# Out:
# [-1, 0, 5, 2, 7]

# %%
def double_pairs(lst):
  return[(x,x*2)for x in lst if x%2==1]
double_pairs([1,2,3])
# Out:
# [(1, 2), (3, 6)]

# %%
nums=[1,2,3]
for i in range(len(nums)):
  nums[i]+=1
print(nums)
# Out:
# [2, 3, 4]

# %%
scans=[[1,0,1],[0,1,0],[1,0,0]]
alert=[]
for i in range(len(scans)):
  row_cont=0
  for j in range(len(scans[i])):
    if scans[i][j]==1:
      row_cont+=1
  if row_cont>1:
    alert.append(f"row{i}quarantine")
print(alert)
# Out:
# ['row0quarantine']

# %%
t=(1,2,3)
t2=t
t2=t2+(4,)
print(t2)
# Out:
# (1, 2, 3, 4)
