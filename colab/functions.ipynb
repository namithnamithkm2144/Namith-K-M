# %%
def number_of_crops():
  return 50
number_of_crops()
# Out:
# 50

# %%
def weather_uptake():
  print("the weather today is sunny with no rain expected")
weather_uptake()
# Out:
# 'the weather today is sunny with no rain expected'

# %%
def plant_info(plant_name):
  print(f"the{plant_name},requires atleast 8 hrs of sunlight per day")
plant_info("tomato")
# Out:
# thetomato,requires atleast 8 hrs of sunlight per day

# %%
def water_needs(plant_type):
  if plant_type=="corn":
    return 50
  elif plant_type =="wheat":
    return 20
  else:
    return 25
water_needs("corn")
# Out:
# 50

# %%
def weather_condition():
  temperature=20
  humidity=70
  return temperature,humidity
temp,hum=weather_condition()
print(f"the temperature is {temp} and the humidity is {hum}")
# Out:
# the temperature is 20 and the humidity is 70

# %%
def ready_for_harvest(days_since_planted):
  if days_since_planted>=120:
    return True
  else:
    return False
ready_for_harvest(100)
# Out:
# False

# %%
def irrrigation_needed(moisture_level,rainfall):
  if moisture_level <40 and  rainfall <10:
    print("irrigation needed")
  else:
    print("irigation is not needed")
irrrigation_needed(45,15)
# Out:
# irigation is not needed

# %%
def total_yield(area,yield_per_acre):
  return area*yield_per_acre
total_yield(2,200)
# Out:
# 400

# %%
def total_yield():
  area=int(input("enterthe araea"))
  yield_per_hectare=int(input("enter the yield per hectare"))
  calculated_yield =area*yield_per_hectare
  return calculated_yield
y=total_yield()
print(y)
# Out:
# enterthe araea5
# enter the yield per hectare5424
# 27120

# %%
def add(x,y):
 return x+y

def subtract(x,y):
  return x-y

def multiply(x,y):
  return x*y

def divide(x,y):
  if y==0:
    return "error! division by zero"
  else:
    return x/y

def get_input():
  try:
    x=float(input("enter the first number:"))
    y=float(input("enter the second number:"))
    return x,y
  except ValueError:
    print("invalid input! please enter valid numbers.")
    return get_input()

def print_menu():
  print("\n select operation:")
  print("1.add")
  print("2.subtract")
  print("3.multiply")
  print("4.divide")
  print("5.exit")

def calculator():
  while True:
    print_menu()
    choice=input("enter the choice(1\2\3\4\5):")
    if choice=='5':
      print('exiting the program')
    x,y=get_input()

    if choice==1:
      print(f"({x} + {y} = {add(x,y)})")
    elif choice==2:
      print(f"({x} - {y} = {subtract(x,y)})")
    elif choice==3:
      print(f"({x} * {y} = {multiply(x,y)})")
    elif choice==4:
      print(f"({x} / {y} = {divide(x,y)})")
    else :
      print("invalid input! please select a valid operation(1\2\3\4\5).")

    calculator()
