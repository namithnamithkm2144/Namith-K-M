# %%
import pandas as pd
mydata={
  'cars':['BMW','VOLVO','FORD',],
  'passings':[3,7,2]
}
myvar=pd.DataFrame(mydata)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  VOLVO         7
# 2   FORD         2

# %%
import pandas as pd


a=[1,7,2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd
a=[1,3,5,7]
myvar= pd.Series(a,index=['x','y','z','a'])
print(myvar)
print(myvar[0])
# Out:
# x    1
# y    3
# z    5
# a    7
# dtype: int64
# 1
# /tmp/ipython-input-1849682747.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(myvar[0])

# %%
import pandas as pd
a=[1,3,5,7]
myvar= pd.Series(a,index=['x','y','z','a'])
print(myvar)
print(myvar['y'])
# Out:
# x    1
# y    3
# z    5
# a    7
# dtype: int64
# 3

# %%
import pandas as pd
a=[1,3,5,7]
myvar= pd.Series(a,index=["name","dob","date","month"])
print(myvar)
print(myvar['name'])
# Out:
# name     1
# dob      3
# date     5
# month    7
# dtype: int64
# 1

# %%
import pandas as pd
a=[1,3,5,7]
myvar= pd.Series(a,index=[1.2,123,2.2,3.22])
print(myvar)
print(myvar["1.2"])
# Out:
# 1.20      1
# 123.00    3
# 2.20      5
# 3.22      7
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Float64Engine._check_type()
#
# KeyError: '1.2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3286034025.py in <cell line: 0>()
#       3 myvar= pd.Series(a,index=[1.2,123,2.2,3.22])
#       4 print(myvar)
# ----> 5 print(myvar["1.2"])
#
# ...

# %%
import pandas as pd
a=[1,3,5]
myvar= pd.Series(a,index=[200,3944,3645])
print(myvar)
print(myvar[200])
# Out:
# 200     1
# 3944    3
# 3645    5
# dtype: int64
# 1

# %%
import pandas as pd
s=pd.Series([10,20,30])
for val in s:
  print(val)
# Out:
# 10
# 20
# 30

# %%
for idx,val in s.items():
  print(idx,val)
# Out:
# 0 10
# 1 20
# 2 30

# %%
for label in s.index:
  print(label)
for value in s.values:
  print(value)
#s.loc[0]
s.iloc[1]
# Out:
# 0
# 1
# 2
# 10
# 20
# 30
# np.int64(20)

# %%
import pandas as pd

calories ={"day1":428,"day2":845,"day3":863}
myvar=pd.Series(calories)
print(myvar)
# Out:
# day1    428
# day2    845
# day3    863
# dtype: int64
