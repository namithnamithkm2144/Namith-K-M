# %%
thislist=["a","b","c","d"]
print(thislist[-4])
# Out:
# a

# %%
thislist=["spodoptera","xanthomonas","pseudomonas","armigera"]
print(thislist[2:4])
print(thislist[-4:0])
print(thislist[:3])
# Out:
# ['pseudomonas', 'armigera']
# []
# ['spodoptera', 'xanthomonas', 'pseudomonas']

# %%
thelist=["lactose","maltose","sucrose","fructose","glucose"]
thelist[3]="starch"
print(thelist)
thelist[2:4]=["amylose","phenyle","pyruvate"]
print(thelist)
# Out:
# ['lactose', 'maltose', 'sucrose', 'starch', 'glucose']
# ['lactose', 'maltose', 'amylose', 'phenyle', 'pyruvate', 'glucose']

# %%
thelist=["pathology","entomology","agro meterology","soilscience"]
thelist.insert(1,"social science")
thelist.append("microbiology")
print(thelist)
# Out:
# ['pathology', 'social science', 'entomology', 'agro meterology', 'soilscience', 'microbiology']

# %%
plant_science=["genetics","breeding","seed science","pathology"]
physical_science=["soilscience","meterology","physics","environmental science"]
agricultural_science=plant_science+physical_science
print(agricultural_science)
# Out:
# ['genetics', 'breeding', 'seed science', 'pathology', 'soilscience', 'meterology', 'physics', 'environmental science']

# %%
thelist=["mango","computer","printer","cpu"]
thelist.remove("mango")
print(thelist)
thelist.pop(2)
print(thelist)
del thelist[0]
print(thelist)
thelist.clear()
print(thelist)
# Out:
# ['computer', 'printer', 'cpu']
# ['computer', 'printer']
# ['printer']
# []

# %% [markdown]
# **bold text**

# %%
thelist=["ma","pa","bro","da","mam"]
thelist.remove("da")
print(thelist)
thelist.extend("mango")
print(thelist)
# Out:
# ['ma', 'pa', 'bro', 'mam']
# ['ma', 'pa', 'bro', 'mam', 'm', 'a', 'n', 'g', 'o']
