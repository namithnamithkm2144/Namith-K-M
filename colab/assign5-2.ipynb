# %%
crops=["Wheat","Rice","Maize","Bajra","Ragi"]
yield_per_acre=[324,432,323,222,322,133]
for crop,crop_yield in zip(crops,yield_per_acre):
  print(crop,"total yield:",crop_yield*10,"quintals")

# %%
rainfall=(23,323,435,462,43,343,455,34,977,37,5866)
print("maxium rainfall:",max(rainfall))
print("minimum rainfall:",min(rainfall))
print("average rainfall:",sum(rainfall)/len(rainfall))
# Out:
# maxium rainfall: 5866
# minimum rainfall: 23
# average rainfall: 818.0

# %%
price_data={"wheat":3748,"rice":874,"maize":743,"ragi":367}
print(price_data)
for key,values in price_data.items():
  print(f"{values}")
# Out:
# {'wheat': 3748, 'rice': 874, 'maize': 743, 'ragi': 367}
# 3748
# 874
# 743
# 367
