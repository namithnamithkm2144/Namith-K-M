# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[12,34,44,29,23,45,65]
plt.plot(x,y,marker='*',linestyle='-.',color='#AA2160',linewidth=2,markersize=8,label='Sales')
plt.title('sales data')
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[12,34,44,29,23,45,65]
size=[12,32,342,54,54,34]
plt.scatter(x,y,s=size)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2156061761.py in <cell line: 0>()
#       3 y=[12,34,44,29,23,45,65]
#       4 size=[12,32,342,54,54,34]
# ----> 5 plt.scatter(x,y,s=size)
#       6 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3937     **kwargs,
#    3938 ) -> PathCollection:
# ...

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[12,34,44,29,23,45,65]
size=[12,32,342,54,54,34,20]
plt.scatter(x,y,s=size)
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()
plt.plot(x,y)
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[12,34,44,29,23,45,65]
plt.plot(x,y,'o:k')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[12,34,44,29,23,45,65]
s=[12,32,342,54,54,34,20]
plt.plot(x,y,label='Line1',color='red')
plt.plot(x,s,label='Line2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[12,34,44,29,23,45,65]
colors=['red','blue','orange','purple','yellow','skyblue','black']
plt.scatter(x,y,c=colors)
plt.colorbar()
plt.show()
plt.plot(x,y,marker='^',color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
size=[10,20,30,40,50]
colors=['red','blue','green','purple','orange']
plt.scatter(x,y,c=colors,s=size)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
sizes=5000*np.random.rand(50)
colours=np.random.rand(50)

plt.scatter(x,y,s=sizes,c=colours,cmap='viridis',alpha=0.8)
plt.colorbar()
plt.title("ADVANCED SCATTER PLOT")
plt.xlabel("x values")
plt.ylabel("y values")
plt.show()

# %%
x=[1,2,3,4,5]
y=[10,12,14,16,18]
values=[5,4,3,2,1]
plt.scatter(x,y,c=values)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=["A","B","C","D"]
y=[3,8,1,10]
plt.bar(x,y,color='orange')
plt.show()

# %%
x=["APPLE","BANANNAS"]
y=[400,350]
cr=["red","yellow"]
plt.bar(x,y,color=cr)
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y,height=0.5)
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y,width=0.6)
plt.show()

# %%
x=np.random.normal(170,10,230)
plt.hist(x)
plt.show()

# %%
data=np.random.normal(170,10,250)
plt.hist(data,bins=20)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram Example")
plt.show()

# %%
data=[2,4,7,8,10,12,13,15,17,18,20,22,24,25,27,29,30,32,35]
plt.hist(data,bins=5,edgecolor="blue")
plt.title('Histogram With 5 Bins')
plt.show()

# %%
data=[2,4,7,8,10,12,13,15,17,18,20,22,24,25,27,29,30,32,35]
plt.hist(data,bins=10,edgecolor="blue")
plt.title('Histogram With 10 Bins')
plt.show()

# %%
data=[2,4,7,8,10,12,13,15,17,18,20,22,24,25,27,29,30,32,35]
plt.hist(data,bins=20 ,edgecolor="blue")
plt.title('Histogram With 20 Bins')
plt.show()

# %%
data=np.random.normal(170,10,250)
plt.hist(data,bins=40,alpha=1)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram Example")
plt.show()

# %%
import matplotlib.pyplot as plt

data=[30,35,40,42,45,47,48,49,50,50,51,52,53,55,57,60,62,65,70,75]
plt.figure(figsize=(8,5))
plt.hist(data,bins=5,color='darkblue',edgecolor='black',alpha=0.5,density=True,range=(30,80))
plt.xlabel("value")
plt.ylabel("Density")
plt.title("histogram without random data")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)
x=np.array([4,1,1,3])
y=np.array([10,20,50,40])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,5])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)
x=np.array([0,1,2,50])
y=np.array([3,8,1,10])
plt.subplot(2,3,3)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,120,30,40])
plt.subplot(2,3,4)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([3,20,1,100])
plt.subplot(2,3,5)
plt.plot(x,y)
x=np.array([0,20,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,6)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score
data={
    "Rainfall":[450,520,390,610,480,530,410,590],
    "Temperature":[22,20,25,19,23,21,24,18],
    "Nitrogen":[0.8,1.0,0.6,1.2,0.9,1.1,0.7,1.3],
    "Fertilizer":[120,140,100,160,130,150,110,170],
    "Yield":[3.5,4.2,2.9,4.8,3.8,4.4,3.1,5.0]

}
df=pd.DataFrame(data)
print(df)
X=df[["Rainfall","Temperature","Nitrogen","Fertilizer"]]
y=df[["Yield"]]
print("X DATA \n",X)
print("\n y DATA\n ",y)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)
print('\n\n')
print("X TRAIN VALUES \n",X_train)
print("\n X TEST VALUES\n",X_test)

model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("\n\n")
print("Mean Absolute Error:",round(mae,2))
print("R2 Score:",round(r2,2))

new_data=np.array([[410,24,0.7,110]])
predicted_yield=model.predict(new_data)
print("Predicted Yield (tons/ha):",round(predicted_yield[0][0],2))
# Out:
#    Rainfall  Temperature  Nitrogen  Fertilizer  Yield
# 0       450           22       0.8         120    3.5
# 1       520           20       1.0         140    4.2
# 2       390           25       0.6         100    2.9
# 3       610           19       1.2         160    4.8
# 4       480           23       0.9         130    3.8
# 5       530           21       1.1         150    4.4
# 6       410           24       0.7         110    3.1
# 7       590           18       1.3         170    5.0
# X DATA
#     Rainfall  Temperature  Nitrogen  Fertilizer
# 0       450           22       0.8         120
# 1       520           20       1.0         140
# 2       390           25       0.6         100
# 3       610           19       1.2         160
# 4       480           23       0.9         130
# 5       530           21       1.1         150
# 6       410           24       0.7         110
# 7       590           18       1.3         170
#
#  y DATA
#      Yield
# 0    3.5
# ...
